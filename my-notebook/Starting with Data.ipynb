# %%
pwd
# Out:
# '/Users/catherinezhou/Desktop/my-notebook'

# %%
pwd
# Out:
# '/Users/catherinezhou/Desktop/my-notebook'

# %%
cd ~/Desktop/data
# Out:
# /Users/catherinezhou/Desktop/data

# %%
pwd
# Out:
# '/Users/catherinezhou/Desktop/data'

# %%
import pandas as pd

# %%
pd.read_csv("data/surveys.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-2d10f2ed9f02> in <module>()
# ----> 1 pd.read_csv("data/surveys.csv")
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'data/surveys.csv' does not exist

# %%
pd.read_csv("surveys.csv")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# 11            12      7   16  1977        7         DM    M             38.0
# 12            13      7   16  1977        3         DM    M             35.0
# 13            14      7   16  1977        8         DM  NaN              NaN
# 14            15      7   16  1977        6         DM    F             36.0
# 15            16      7   16  1977        4         DM    F             36.0
# 16            17      7   16  1977        3         DS    F             48.0
# 17            18      7   16  1977        2         PP    M             22.0
# 18            19      7   16  1977        4         PF  NaN              NaN
# 19            20      7   17  1977       11         DS    F             48.0
# 20            21      7   17  1977       14         DM    F             34.0
# 21            22      7   17  1977       15         NL    F             31.0
# 22            23      7   17  1977       13         DM    M             36.0
# 23            24      7   17  1977       13         SH    M             21.0
# 24            25      7   17  1977        9         DM    M             35.0
# 25            26      7   17  1977       15         DM    M             31.0
# 26            27      7   17  1977       15         DM    M             36.0
# 27            28      7   17  1977       11         DM    M             38.0
# 28            29      7   17  1977       11         PP    M              NaN
# 29            30      7   17  1977       10         DS    F             52.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35519      35520     12   31  2002        9         SF  NaN             24.0
# 35520      35521     12   31  2002        9         DM    M             37.0
# 35521      35522     12   31  2002        9         DM    F             35.0
# 35522      35523     12   31  2002        9         DM    F             36.0
# 35523      35524     12   31  2002        9         PB    F             25.0
# 35524      35525     12   31  2002        9         OL    M             21.0
# 35525      35526     12   31  2002        8         OT    F             20.0
# 35526      35527     12   31  2002       13         DO    F             33.0
# 35527      35528     12   31  2002       13         US  NaN              NaN
# 35528      35529     12   31  2002       13         PB    F             25.0
# 35529      35530     12   31  2002       13         OT    F             20.0
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35531      35532     12   31  2002       14         DM    F             34.0
# 35532      35533     12   31  2002       14         DM    F             36.0
# 35533      35534     12   31  2002       14         DM    M             37.0
# 35534      35535     12   31  2002       14         DM    M             37.0
# 35535      35536     12   31  2002       14         DM    F             35.0
# 35536      35537     12   31  2002       14         DM    F             36.0
# 35537      35538     12   31  2002       15         PB    F             26.0
# 35538      35539     12   31  2002       15         SF    M             26.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# ...       ...
# 35519    36.0
# 35520    48.0
# 35521    45.0
# 35522    44.0
# 35523    27.0
# 35524    26.0
# 35525    24.0
# 35526    43.0
# 35527     NaN
# 35528    25.0
# 35529     NaN
# 35530     NaN
# 35531    43.0
# 35532    48.0
# 35533    56.0
# 35534    53.0
# 35535    42.0
# 35536    46.0
# 35537    31.0
# 35538    68.0
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
#
# [35549 rows x 9 columns]

# %%
cd ~/Desktop
# Out:
# /Users/catherinezhou/Desktop

# %%
pwd
# Out:
# '/Users/catherinezhou/Desktop'

# %%
pd.read_csv("data/surveys.csv"
# Out:
#   File "<ipython-input-10-c1dfa748b4df>", line 1
#     pd.read_csv("data/surveys.csv"
#                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
pd.read_csv("data/surveys.csv")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# 11            12      7   16  1977        7         DM    M             38.0
# 12            13      7   16  1977        3         DM    M             35.0
# 13            14      7   16  1977        8         DM  NaN              NaN
# 14            15      7   16  1977        6         DM    F             36.0
# 15            16      7   16  1977        4         DM    F             36.0
# 16            17      7   16  1977        3         DS    F             48.0
# 17            18      7   16  1977        2         PP    M             22.0
# 18            19      7   16  1977        4         PF  NaN              NaN
# 19            20      7   17  1977       11         DS    F             48.0
# 20            21      7   17  1977       14         DM    F             34.0
# 21            22      7   17  1977       15         NL    F             31.0
# 22            23      7   17  1977       13         DM    M             36.0
# 23            24      7   17  1977       13         SH    M             21.0
# 24            25      7   17  1977        9         DM    M             35.0
# 25            26      7   17  1977       15         DM    M             31.0
# 26            27      7   17  1977       15         DM    M             36.0
# 27            28      7   17  1977       11         DM    M             38.0
# 28            29      7   17  1977       11         PP    M              NaN
# 29            30      7   17  1977       10         DS    F             52.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35519      35520     12   31  2002        9         SF  NaN             24.0
# 35520      35521     12   31  2002        9         DM    M             37.0
# 35521      35522     12   31  2002        9         DM    F             35.0
# 35522      35523     12   31  2002        9         DM    F             36.0
# 35523      35524     12   31  2002        9         PB    F             25.0
# 35524      35525     12   31  2002        9         OL    M             21.0
# 35525      35526     12   31  2002        8         OT    F             20.0
# 35526      35527     12   31  2002       13         DO    F             33.0
# 35527      35528     12   31  2002       13         US  NaN              NaN
# 35528      35529     12   31  2002       13         PB    F             25.0
# 35529      35530     12   31  2002       13         OT    F             20.0
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35531      35532     12   31  2002       14         DM    F             34.0
# 35532      35533     12   31  2002       14         DM    F             36.0
# 35533      35534     12   31  2002       14         DM    M             37.0
# 35534      35535     12   31  2002       14         DM    M             37.0
# 35535      35536     12   31  2002       14         DM    F             35.0
# 35536      35537     12   31  2002       14         DM    F             36.0
# 35537      35538     12   31  2002       15         PB    F             26.0
# 35538      35539     12   31  2002       15         SF    M             26.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# ...       ...
# 35519    36.0
# 35520    48.0
# 35521    45.0
# 35522    44.0
# 35523    27.0
# 35524    26.0
# 35525    24.0
# 35526    43.0
# 35527     NaN
# 35528    25.0
# 35529     NaN
# 35530     NaN
# 35531    43.0
# 35532    48.0
# 35533    56.0
# 35534    53.0
# 35535    42.0
# 35536    46.0
# 35537    31.0
# 35538    68.0
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
#
# [35549 rows x 9 columns]

# %%
surveys_df = pd.read_csv("data/surveys.csv")

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# 11            12      7   16  1977        7         DM    M             38.0
# 12            13      7   16  1977        3         DM    M             35.0
# 13            14      7   16  1977        8         DM  NaN              NaN
# 14            15      7   16  1977        6         DM    F             36.0
# 15            16      7   16  1977        4         DM    F             36.0
# 16            17      7   16  1977        3         DS    F             48.0
# 17            18      7   16  1977        2         PP    M             22.0
# 18            19      7   16  1977        4         PF  NaN              NaN
# 19            20      7   17  1977       11         DS    F             48.0
# 20            21      7   17  1977       14         DM    F             34.0
# 21            22      7   17  1977       15         NL    F             31.0
# 22            23      7   17  1977       13         DM    M             36.0
# 23            24      7   17  1977       13         SH    M             21.0
# 24            25      7   17  1977        9         DM    M             35.0
# 25            26      7   17  1977       15         DM    M             31.0
# 26            27      7   17  1977       15         DM    M             36.0
# 27            28      7   17  1977       11         DM    M             38.0
# 28            29      7   17  1977       11         PP    M              NaN
# 29            30      7   17  1977       10         DS    F             52.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35519      35520     12   31  2002        9         SF  NaN             24.0
# 35520      35521     12   31  2002        9         DM    M             37.0
# 35521      35522     12   31  2002        9         DM    F             35.0
# 35522      35523     12   31  2002        9         DM    F             36.0
# 35523      35524     12   31  2002        9         PB    F             25.0
# 35524      35525     12   31  2002        9         OL    M             21.0
# 35525      35526     12   31  2002        8         OT    F             20.0
# 35526      35527     12   31  2002       13         DO    F             33.0
# 35527      35528     12   31  2002       13         US  NaN              NaN
# 35528      35529     12   31  2002       13         PB    F             25.0
# 35529      35530     12   31  2002       13         OT    F             20.0
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35531      35532     12   31  2002       14         DM    F             34.0
# 35532      35533     12   31  2002       14         DM    F             36.0
# 35533      35534     12   31  2002       14         DM    M             37.0
# 35534      35535     12   31  2002       14         DM    M             37.0
# 35535      35536     12   31  2002       14         DM    F             35.0
# 35536      35537     12   31  2002       14         DM    F             36.0
# 35537      35538     12   31  2002       15         PB    F             26.0
# 35538      35539     12   31  2002       15         SF    M             26.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# ...       ...
# 35519    36.0
# 35520    48.0
# 35521    45.0
# 35522    44.0
# 35523    27.0
# 35524    26.0
# 35525    24.0
# 35526    43.0
# 35527     NaN
# 35528    25.0
# 35529     NaN
# 35530     NaN
# 35531    43.0
# 35532    48.0
# 35533    56.0
# 35534    53.0
# 35535    42.0
# 35536    46.0
# 35537    31.0
# 35538    68.0
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
#
# [35549 rows x 9 columns]

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df.head()
surveys_df.head(15)
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10         11      7   16  1977        5         DS    F             53.0
# 11         12      7   16  1977        7         DM    M             38.0
# 12         13      7   16  1977        3         DM    M             35.0
# 13         14      7   16  1977        8         DM  NaN              NaN
# 14         15      7   16  1977        6         DM    F             36.0
#
#     weight
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN

# %%
surveys_df.head(15)
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10         11      7   16  1977        5         DS    F             53.0
# 11         12      7   16  1977        7         DM    M             38.0
# 12         13      7   16  1977        3         DM    M             35.0
# 13         14      7   16  1977        8         DM  NaN              NaN
# 14         15      7   16  1977        6         DM    F             36.0
#
#     weight
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN

# %%
surveys_df.tail
# Out:
# <bound method NDFrame.tail of        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# 11            12      7   16  1977        7         DM    M             38.0
# 12            13      7   16  1977        3         DM    M             35.0
# 13            14      7   16  1977        8         DM  NaN              NaN
# 14            15      7   16  1977        6         DM    F             36.0
# 15            16      7   16  1977        4         DM    F             36.0
# 16            17      7   16  1977        3         DS    F             48.0
# 17            18      7   16  1977        2         PP    M             22.0
# 18            19      7   16  1977        4         PF  NaN              NaN
# 19            20      7   17  1977       11         DS    F             48.0
# 20            21      7   17  1977       14         DM    F             34.0
# 21            22      7   17  1977       15         NL    F             31.0
# 22            23      7   17  1977       13         DM    M             36.0
# 23            24      7   17  1977       13         SH    M             21.0
# 24            25      7   17  1977        9         DM    M             35.0
# 25            26      7   17  1977       15         DM    M             31.0
# 26            27      7   17  1977       15         DM    M             36.0
# 27            28      7   17  1977       11         DM    M             38.0
# 28            29      7   17  1977       11         PP    M              NaN
# 29            30      7   17  1977       10         DS    F             52.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35519      35520     12   31  2002        9         SF  NaN             24.0
# 35520      35521     12   31  2002        9         DM    M             37.0
# 35521      35522     12   31  2002        9         DM    F             35.0
# 35522      35523     12   31  2002        9         DM    F             36.0
# 35523      35524     12   31  2002        9         PB    F             25.0
# 35524      35525     12   31  2002        9         OL    M             21.0
# 35525      35526     12   31  2002        8         OT    F             20.0
# 35526      35527     12   31  2002       13         DO    F             33.0
# 35527      35528     12   31  2002       13         US  NaN              NaN
# 35528      35529     12   31  2002       13         PB    F             25.0
# 35529      35530     12   31  2002       13         OT    F             20.0
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35531      35532     12   31  2002       14         DM    F             34.0
# 35532      35533     12   31  2002       14         DM    F             36.0
# 35533      35534     12   31  2002       14         DM    M             37.0
# 35534      35535     12   31  2002       14         DM    M             37.0
# 35535      35536     12   31  2002       14         DM    F             35.0
# 35536      35537     12   31  2002       14         DM    F             36.0
# 35537      35538     12   31  2002       15         PB    F             26.0
# 35538      35539     12   31  2002       15         SF    M             26.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# ...       ...
# 35519    36.0
# 35520    48.0
# 35521    45.0
# 35522    44.0
# 35523    27.0
# 35524    26.0
# 35525    24.0
# 35526    43.0
# 35527     NaN
# 35528    25.0
# 35529     NaN
# 35530     NaN
# 35531    43.0
# 35532    48.0
# 35533    56.0
# 35534    53.0
# 35535    42.0
# 35536    46.0
# 35537    31.0
# 35538    68.0
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
#
# [35549 rows x 9 columns]>

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
site_names = pd.unique(surveys_df['species_id'])

# %%
site_names
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
len(site_names)
# Out:
# 49

# %%
surveys_df['plot_id'].nunique()
# Out:
# 24

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
surveys_df['weight'].min()
surveys_df['weight'].max()
surveys_df['weight'].mean()
surveys_df['weight'].std()
surveys_df['weight'].count()
# Out:
# 32283

# %%
surveys_df['weight'].min()
# Out:
# 4.0

# %%
grouped_data = surveys_df.groupby('sex')

# %%
grouped_data.describe()
# Out:
#          day                                                  hindfoot_length  \
#        count       mean       std  min  25%   50%   75%   max           count
# sex
# F    15690.0  16.007138  8.271144  1.0  9.0  16.0  23.0  31.0         14894.0
# M    17348.0  16.184286  8.199274  1.0  9.0  16.0  23.0  31.0         16476.0
#
#                  ...   weight            year                                 \
# 18      F    17940.875497  6.698013  15.960265  1990.536424        26.690341
#         M    15106.718850  6.610224  16.797125  1988.551118        27.703072
# 19      F    21848.216475  6.701149  15.226054  1993.417625        21.257937
#         M    19470.779690  6.533563  16.647160  1991.740103        21.071685
# 20      F    17510.769231  6.743077  16.026154  1990.253846        27.069193
#         M    16076.192496  6.489396  16.375204  1989.243067        27.908451
# 21      F    22452.636661  6.860884  16.307692  1993.878887        22.366554
#         M    20120.399113  6.671840  16.203991  1992.199557        21.736721
# 22      F    18499.695976  6.651267  15.521610  1990.973174        34.108320
#         M    18015.365527  6.381872  16.682021  1990.650817        33.359746
# 23      F    15863.193939  6.860606  16.036364  1989.024242        20.051948
#         M    17091.338164  6.391304  16.077295  1989.961353        19.850000
# 24      F    13702.224280  6.596708  16.393004  1987.485597        26.993377
#         M    15208.136082  6.360825  16.971134  1988.641237        25.786996
#
#                 weight
# plot_id sex
# 1       F    46.311138
#         M    55.950560
# 2       F    52.561845
#         M    51.391382
# 3       F    31.215349
#         M    34.163241
# 4       F    46.818824
#         M    48.888119
# 5       F    40.974806
#         M    40.708551
# 6       F    36.352288
#         M    36.867388
# 7       F    20.006135
#         M    21.194719
# 8       F    45.623011
#         M    49.641372
# 9       F    53.618469
#         M    49.519309
# 10      F    17.094203
#         M    19.971223
# 11      F    43.515075
#         M    43.366197
# 12      F    49.831731
#         M    48.909710
# 13      F    40.524590
#         M    40.097754
# 14      F    47.355491
#         M    45.159378
# 15      F    26.670236
#         M    27.523691
# 16      F    25.810427
#         M    23.811321
# 17      F    48.176201
#         M    47.558853
# 18      F    36.963514
#         M    43.546952
# 19      F    21.978599
#         M    20.306878
# 20      F    52.624406
#         M    44.197279
# 21      F    25.974832
#         M    22.772622
# 22      F    53.647059
#         M    54.572531
# 23      F    20.564417
#         M    18.941463
# 24      F    47.914405
#         M    39.321503

# %%
grouped_data = surveys_df.groupby('weight')

# %%
grouped_data.describe()
# Out:
#           day                                                        \
#         count       mean        std   min    25%   50%    75%   max
# weight
# 4.0      17.0  16.823529   6.424906   5.0  13.00  19.0  20.00  28.0
# 5.0      58.0  16.086207   6.941572   1.0  13.00  16.0  21.75  28.0
# 6.0     186.0  16.188172   7.434912   1.0  10.00  16.0  22.00  31.0
# 7.0     552.0  15.797101   7.550108   1.0  10.00  15.0  22.00  31.0
# 8.0     667.0  16.430285   7.760057   1.0  11.00  15.0  23.00  31.0
# 9.0     742.0  15.933962   8.274782   1.0   9.00  15.0  23.00  31.0
# 10.0    759.0  15.301713   8.493976   1.0   8.00  14.0  23.00  31.0
# 11.0    661.0  15.649017   8.051781   1.0   9.00  15.0  22.00  31.0
# 12.0    468.0  15.299145   8.141695   1.0   9.00  15.0  21.00  31.0
# 13.0    395.0  15.020253   8.292838   1.0   9.00  14.0  22.00  31.0
# 14.0    433.0  15.542725   8.786756   1.0   8.00  15.0  23.00  31.0
# 252.0   1991.500000  13.435029  1982.0  1986.75  1991.5  1996.25  2001.0
# 253.0   1987.000000        NaN  1987.0  1987.00  1987.0  1987.00  1987.0
# 256.0   1983.000000        NaN  1983.0  1983.00  1983.0  1983.00  1983.0
# 259.0   1985.500000   2.121320  1984.0  1984.75  1985.5  1986.25  1987.0
# 260.0   1987.000000   0.000000  1987.0  1987.00  1987.0  1987.00  1987.0
# 264.0   1981.000000        NaN  1981.0  1981.00  1981.0  1981.00  1981.0
# 265.0   2000.000000        NaN  2000.0  2000.00  2000.0  2000.00  2000.0
# 269.0   1987.000000        NaN  1987.0  1987.00  1987.0  1987.00  1987.0
# 270.0   1987.000000        NaN  1987.0  1987.00  1987.0  1987.00  1987.0
# 274.0   1979.000000        NaN  1979.0  1979.00  1979.0  1979.00  1979.0
# 275.0   1989.000000        NaN  1989.0  1989.00  1989.0  1989.00  1989.0
# 278.0   1987.000000        NaN  1987.0  1987.00  1987.0  1987.00  1987.0
# 280.0   2001.000000        NaN  2001.0  2001.00  2001.0  2001.00  2001.0
#
# [255 rows x 48 columns]

# %%
by_site['weight'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-6b52cb1320a0> in <module>()
# ----> 1 by_site['weight'].describe()
#
# NameError: name 'by_site' is not defined

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
by_site = surveys_df.groupby('site')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-638f16eea12e> in <module>()
# ----> 1 by_site = surveys_df.groupby('site')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6657         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6658                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6659                        observed=observed, **kwargs)
#    6660
#    6661     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'site'

# %%
by_site = surveys_df.groupby('plot_id')

# %%
by_site['weight'].describe()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# plot_id
# 1        1903.0  51.822911  38.176670  4.0  30.0  44.0  53.0  231.0
# 2        2074.0  52.251688  46.503602  5.0  24.0  41.0  50.0  278.0
# 3        1710.0  32.654386  35.641630  4.0  14.0  23.0  36.0  250.0
# 4        1866.0  47.928189  32.886598  4.0  30.0  43.0  50.0  200.0
# 5        1092.0  40.947802  34.086616  5.0  21.0  37.0  48.0  248.0
# 6        1463.0  36.738893  30.648310  5.0  18.0  30.0  45.0  243.0
# 7         638.0  20.663009  21.315325  4.0  11.0  17.0  23.0  235.0
# 8        1781.0  47.758001  33.192194  5.0  26.0  44.0  51.0  178.0
# 9        1811.0  51.432358  33.724726  6.0  36.0  45.0  50.0  275.0
# 10        279.0  18.541219  20.290806  4.0  10.0  12.0  21.0  237.0
# 11       1793.0  43.451757  28.975514  5.0  26.0  42.0  48.0  212.0
# 12       2219.0  49.496169  41.630035  6.0  26.0  42.0  50.0  280.0
# 13       1371.0  40.445660  34.042767  5.0  20.5  33.0  45.0  241.0
# 14       1728.0  46.277199  27.570389  5.0  36.0  44.0  49.0  222.0
# 15        869.0  27.042578  35.178142  4.0  11.0  18.0  26.0  259.0
# 16        480.0  24.585417  17.682334  4.0  12.0  20.0  34.0  158.0
# 17       1893.0  47.889593  35.802399  4.0  27.0  42.0  50.0  216.0
# 18       1351.0  40.005922  38.480856  5.0  17.5  30.0  44.0  256.0
# 19       1084.0  21.105166  13.269840  4.0  11.0  19.0  27.0  139.0
# 20       1222.0  48.665303  50.111539  5.0  17.0  31.0  47.0  223.0
# 21       1029.0  24.627794  21.199819  4.0  10.0  22.0  31.0  190.0
# 22       1298.0  54.146379  38.743967  5.0  29.0  42.0  54.0  212.0
# 23        369.0  19.634146  18.382678  4.0  10.0  14.0  23.0  199.0
# 24        960.0  43.679167  45.936588  4.0  19.0  27.5  45.0  251.0

# %%
plot_id = 1

# %%
plot_id = site
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-f1721e989724> in <module>()
# ----> 1 plot_id = site
#
# NameError: name 'site' is not defined

# %%
PF['weight'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-334ac7baff8a> in <module>()
# ----> 1 PF['weight'].describe()
#
# NameError: name 'PF' is not defined

# %%
species_counts = surveys_df.groupby('species_id')['record_id'].count()
print(species_counts)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
surveys_df.groupby('species_id')['record_id'].count()['DO']
# Out:
# 3027

# %%
surveys_df['weight']*2
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
#          ...
# 35519     72.0
# 35520     96.0
# 35521     90.0
# 35522     88.0
# 35523     54.0
# 35524     52.0
# 35525     48.0
# 35526     86.0
# 35527      NaN
# 35528     50.0
# 35529      NaN
# 35530      NaN
# 35531     86.0
# 35532     96.0
# 35533    112.0
# 35534    106.0
# 35535     84.0
# 35536     92.0
# 35537     62.0
# 35538    136.0
# 35539     46.0
# 35540     62.0
# 35541     58.0
# 35542     68.0
# 35543      NaN
# 35544      NaN
# 35545      NaN
# 35546     28.0
# 35547    102.0
# 35548      NaN
# Name: weight, Length: 35549, dtype: float64

# %%
# %matplotlib inline

# %%
species_counts.plot(kind='bar');

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()

# %%
total_count.plot(kind='bar');

# %%
# Create a plot of average weight across all species per site.
# Create a plot of total males versus total females for the entire dataset.

# %%
cd ~/Desktop/data
import pandas as pd
# Out:
#   File "<ipython-input-1-162c4e32ae9c>", line 1
#     cd ~/Desktop/data
#        ^
# SyntaxError: invalid syntax

# %%
cd ~/Desktop/data
# Out:
# /Users/catherinezhou/Desktop/data

# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/catherinezhou/Desktop/data'
